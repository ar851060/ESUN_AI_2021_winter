# %% [markdown]
# <a href="https://colab.research.google.com/github/ar851060/ESUN_AI_2021_winter/blob/main/10_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import os
import pathlib
from sklearn.inspection import PartialDependenceDisplay
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import pickle

# %% [markdown]
# # Randomforest

# %%
comb = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/Output/importance/RF_2_correct.csv")

# pred = list(map(str, [2,6,10,12,13,15,18,19,21,22,25,26,36,37,39,48]))
pred = list(map(str, [6,10,12,13,15,18,19,21,22,25,26,36,37,39,48]))
for i in pred:
  data = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/Output/importance/RF_"+i+"_correct.csv")['0']
  comb = pd.concat([comb,data],axis=1)

# %%
comb = comb.set_index('Unnamed: 0')
comb.index.names = ['Variables']
comb.columns.names = ['shop_tag']
comb.columns = list(map(str, [2,6,10,12,13,15,18,19,21,22,25,26,36,37,39,48]))
comb = round(comb, 3)

# %%
comb

# %%
comb.style.apply(lambda x: ["background: #D94C8D" if abs(v) > 0.05 else "" for v in x], axis = 1)\
     .apply(lambda x: ["background: #C82E75" if abs(v) > 0.07 else "" for v in x], axis = 1)\
     .apply(lambda x: ["background: #B91C64" if abs(v) > 0.1 else "" for v in x], axis = 1)\
     .apply(lambda x: ["background: #A30B51" if abs(v) > 0.2 else "" for v in x], axis = 1)\
     .apply(lambda x: ["color: white" if abs(v) > 0.05 else "" for v in x], axis = 1).format('{0:,.3f}')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# # Dependence plot(RF)

# %%
# [2,6,10,12,13,15,18,19,21,22,25,26,36,37,39,48]
tag = "2"


X_2 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_2 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_2 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_2 = regr_2.fit(X_2, y_2)
del y_2

tag = "6"

X_6 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_6 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_6 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_6 = regr_6.fit(X_6, y_6)
del y_6

tag = "10"

X_10 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_10 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_10 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_10 = regr_10.fit(X_10, y_10)
del y_10

tag = "12"

X_12 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_12 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_12 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_12 = regr_12.fit(X_12, y_12)
del y_12

tag = "13"

X_13 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_13 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_13 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_13 = regr_13.fit(X_13, y_13)
del y_13

tag = "15"

X_15 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_15 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_15 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_15 = regr_15.fit(X_15, y_15)
del y_15

tag = "18"

X_18 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_18 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_18 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_18 = regr_18.fit(X_18, y_18)
del y_18

tag = "19"

X_19 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_19 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_19 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_19 = regr_19.fit(X_19, y_19)
del y_19

tag = "21"

X_21 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_21 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_21 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_21 = regr_21.fit(X_21, y_21)
del y_21

tag = "22"

X_22 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_22 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_22 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_22 = regr_22.fit(X_22, y_22)
del y_22

tag = "25"

X_25 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_25 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_25 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_25 = regr_25.fit(X_25, y_25)
del y_25

tag = "26"

X_26 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_26 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_26 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_26 = regr_26.fit(X_26, y_26)
del y_26

tag = "37"

X_37 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_37 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_37 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_37 = regr_37.fit(X_37, y_37)
del y_37

tag = "39"

X_39 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_39 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_39 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_39 = regr_39.fit(X_39, y_39)
del y_39

tag = "48"

X_48 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
y_48 = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
regr_48 = RandomForestRegressor(max_depth=None, n_estimators=100, max_samples=0.5, max_features='sqrt')
est_48 = regr_48.fit(X_48, y_48)
del y_48
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
fig, ax = plt.subplots(figsize=(16, 8))
pdp_2 = PartialDependenceDisplay.from_estimator(est_2, X_2, [0, 1, 11, 12, 14, 16, 17, 19], ax=ax, n_cols = 4)
pdp_6 = PartialDependenceDisplay.from_estimator(est_6, X_6, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_2.axes_, line_kw={"color": "blue"}, n_cols = 4)
pdp_10 = PartialDependenceDisplay.from_estimator(est_10, X_10, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_2.axes_, line_kw={"color": "aquamarine"}, n_cols = 4)
pdp_12 = PartialDependenceDisplay.from_estimator(est_12, X_12, [0, 1, 11, 12, 14, 16, 17, 19], ax=ax, line_kw={"color": "darkviolet"}, n_cols = 4)
pdp_13 = PartialDependenceDisplay.from_estimator(est_13, X_13, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_12.axes_, line_kw={"color": "brown"}, n_cols = 4)
pdp_15 = PartialDependenceDisplay.from_estimator(est_15, X_15, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_13.axes_, line_kw={"color": "chartreuse"}, n_cols = 4)
pdp_18 = PartialDependenceDisplay.from_estimator(est_18, X_18, [0, 1, 11, 12, 14, 16, 17, 19], ax=ax, line_kw={"color": "salmon"}, n_cols = 4)
pdp_19 = PartialDependenceDisplay.from_estimator(est_19, X_19, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_18.axes_, line_kw={"color": "deeppink"}, n_cols = 4)
pdp_21 = PartialDependenceDisplay.from_estimator(est_21, X_21, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_19.axes_, line_kw={"color": "darkviolet"}, n_cols = 4)
pdp_22 = PartialDependenceDisplay.from_estimator(est_22, X_22, [0, 1, 11, 12, 14, 16, 17, 19], ax=ax, line_kw={"color": "gray"}, n_cols = 4)
pdp_25 = PartialDependenceDisplay.from_estimator(est_25, X_25, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_22.axes_, line_kw={"color": "darkseagreen"}, n_cols = 4)
pdp_26 = PartialDependenceDisplay.from_estimator(est_26, X_26, [0, 1, 11, 12, 14, 16, 17, 19], ax=pdp_25.axes_, line_kw={"color": "darkgoldenrod"}, n_cols = 4)
pdp_37 = PartialDependenceDisplay.from_estimator(est_37, X_37, [0, 1, 11, 12, 14, 16, 17, 19], ax=ax, line_kw={"color": "darkolivegreen"}, n_cols = 4)
pdp_39 = PartialDependenceDisplay.from_estimator(est_39, X_39, [0, 1, 11, 12, 14, 16, 17, 19], ax=ax, line_kw={"color": "darkolivegreen"}, n_cols = 4)
pdp_48 = PartialDependenceDisplay.from_estimator(est_48, X_48, [0, 1, 11, 12, 14, 16, 17, 19], ax=ax, line_kw={"color": "darkmagenta"}, n_cols = 4)

# %% [markdown]
# # Linear regression

# %%
# 畫迴歸係數信賴區間的圖
# import pickle
# import seaborn as sns
pred = [2,6,10,12,13,15,18,19,21,22,25,26,36,37,39,48]
for j in pred:
  tag = str(j)

  filename = "/content/drive/Shareddrives/統學期末比賽/Output/model/Linear_"+tag+"_correct.sav"
  lm_model = pickle.load(open(filename, 'rb'))

  params = np.append(lm_model.intercept_,lm_model.coef_)

  X = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainx_"+tag+"_base.csv").fillna(0)
  y = pd.read_csv("/content/drive/Shareddrives/統學期末比賽/train_test/"+tag+"/trainy_"+tag+"_base.csv")
  predictions = lm_model.predict(X)
  flat_list = [item for sublist in predictions for item in sublist]
  newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
  MSE = (sum((y['next_txn_amt'] - flat_list)**2))/(len(newX)-len(newX.columns)+1-1)

  # Note if you don't want to use a DataFrame replace the two lines above with
  # newX = np.append(np.ones((len(X),1)), X, axis=1)
  # MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

  var_b = MSE*(np.linalg.pinv(np.dot(newX.T,newX)).diagonal())
  sd_b = np.sqrt(var_b)
  ts_b = params/ sd_b

  # p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-len(newX[0])))) for i in ts_b]

  sd_b = np.round(sd_b,3)*1.96
  ts_b = np.round(ts_b,3)
  # p_values = np.round(p_values,3)
  params = np.round(params,4)

  # myDF3 = pd.DataFrame()
  # myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"] = [params,sd_b,ts_b]
  # print(myDF3)

  x = params[1:21]
  y = range(1,21)
  errors = sd_b[1:21]


  plt.figure(figsize = (12,12))
  plt.errorbar(x, y, xerr=errors, fmt = 'o', color = 'k')
  plt.xlim((-5,5))
  plt.yticks((y), (lm_coef.index)) 
  plt.axvline(x=0, color='red')
  plt.xlabel('Coefficient')
  plt.title('tag '+tag+' coefficients and their confidence intervals')
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in sqrt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in sqrt
